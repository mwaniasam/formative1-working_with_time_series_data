# %% [markdown]
# <a href="https://colab.research.google.com/github/mwaniasam/formative1-working_with_time_series_data/blob/main/Scripts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.2.25)

# %%
import requests
import pandas as pd
import os

# %%
response = requests.get("https://unantlered-ryleigh-phlegmatically.ngrok-free.dev/mongo/records")
data = response.json()

print(len(data))
print(data[0])
# Out:
# 500
# {'_id': '69ab1169c2dc7c3530b4e521', 'timestamp': '2015-01-01T00:00:00', 'load': {'actual': 25385.0, 'forecast': 26118.0}, 'price': {'actual': 65.41, 'day_ahead': 50.1}, 'generation': {'biomass': {'mw': 447.0}, 'fossil_brown_coal': {'mw': 329.0}, 'fossil_coal_derived_gas': {'mw': 0.0}, 'fossil_gas': {'mw': 4844.0}, 'fossil_hard_coal': {'mw': 4821.0}, 'fossil_oil': {'mw': 162.0}, 'fossil_oil_shale': {'mw': 0.0}, 'fossil_peat': {'mw': 0.0}, 'geothermal': {'mw': 0.0}, 'hydro_pumped_storage_cons': {'mw': 863.0}, 'hydro_run_of_river': {'mw': 1051.0}, 'hydro_water_reservoir': {'mw': 1899.0}, 'marine': {'mw': 0.0}, 'nuclear': {'mw': 7096.0}, 'other': {'mw': 43.0}, 'other_renewable': {'mw': 73.0}, 'solar': {'mw': 49.0, 'forecast_mw': 17.0}, 'waste': {'mw': 196.0}, 'wind_offshore': {'mw': 0.0}, 'wind_onshore': {'mw': 6378.0, 'forecast_mw': 6436.0}}, 'energy_summary': {'total_renewable_mw': 9897.0, 'total_fossil_mw': 10156.0, 'total_generation_mw': 28251.0}}

# %%
def flatten_record(record):
    flat = {}
    flat['time'] = record['timestamp']
    flat['total load actual'] = record['load']['actual']
    flat['total load forecast'] = record['load']['forecast']
    flat['price actual'] = record['price']['actual']
    flat['price day ahead'] = record['price']['day_ahead']
    flat['generation biomass'] = record['generation']['biomass']['mw']
    flat['generation fossil brown coal'] = record['generation']['fossil_brown_coal']['mw']
    flat['generation fossil coal-derived gas'] = record['generation']['fossil_coal_derived_gas']['mw']
    flat['generation fossil gas'] = record['generation']['fossil_gas']['mw']
    flat['generation fossil hard coal'] = record['generation']['fossil_hard_coal']['mw']
    flat['generation fossil oil'] = record['generation']['fossil_oil']['mw']
    flat['generation fossil oil shale'] = record['generation']['fossil_oil_shale']['mw']
    flat['generation fossil peat'] = record['generation']['fossil_peat']['mw']
    flat['generation geothermal'] = record['generation']['geothermal']['mw']
    flat['generation hydro pumped storage consumption'] = record['generation']['hydro_pumped_storage_cons']['mw']
    flat['generation hydro run-of-river and poundage'] = record['generation']['hydro_run_of_river']['mw']
    flat['generation hydro water reservoir'] = record['generation']['hydro_water_reservoir']['mw']
    flat['generation marine'] = record['generation']['marine']['mw']
    flat['generation nuclear'] = record['generation']['nuclear']['mw']
    flat['generation other'] = record['generation']['other']['mw']
    flat['generation other renewables'] = record['generation']['other_renewable']['mw']
    flat['generation solar'] = record['generation']['solar']['mw']
    flat['generation solar forecast'] = record['generation']['solar']['forecast_mw']
    flat['generation waste'] = record['generation']['waste']['mw']
    flat['generation wind offshore'] = record['generation']['wind_offshore']['mw']
    flat['generation wind onshore'] = record['generation']['wind_onshore']['mw']
    flat['generation wind onshore forecast'] = record['generation']['wind_onshore']['forecast_mw']

    return flat

# %%
flat_record = flatten_record(data[0])
print(flat_record)
# Out:
# {'time': '2015-01-01T00:00:00', 'total load actual': 25385.0, 'total load forecast': 26118.0, 'price actual': 65.41, 'price day ahead': 50.1, 'generation biomass': 447.0, 'generation fossil brown coal': 329.0, 'generation fossil coal-derived gas': 0.0, 'generation fossil gas': 4844.0, 'generation fossil hard coal': 4821.0, 'generation fossil oil': 162.0, 'generation fossil oil shale': 0.0, 'generation fossil peat': 0.0, 'generation geothermal': 0.0, 'generation hydro pumped storage consumption': 863.0, 'generation hydro run-of-river and poundage': 1051.0, 'generation hydro water reservoir': 1899.0, 'generation marine': 0.0, 'generation nuclear': 7096.0, 'generation other': 43.0, 'generation other renewables': 73.0, 'generation solar': 49.0, 'generation solar forecast': 17.0, 'generation waste': 196.0, 'generation wind offshore': 0.0, 'generation wind onshore': 6378.0, 'generation wind onshore forecast': 6436.0}

# %%
flat_records = [flatten_record(record) for record in data]
df = pd.DataFrame(flat_records)
print(df.shape)
print(df.head())
# Out:
# (500, 27)
#                   time  total load actual  total load forecast  price actual  \
# 0  2015-01-01T00:00:00            25385.0              26118.0         65.41
# 1  2015-01-01T01:00:00            24382.0              24934.0         64.92
# 2  2015-01-01T02:00:00            22734.0              23515.0         64.48
# 3  2015-01-01T03:00:00            21286.0              22642.0         59.32
# 4  2015-01-01T04:00:00            20264.0              21785.0         56.04
#
#    price day ahead  generation biomass  generation fossil brown coal  \
# 0            50.10               447.0                         329.0
# 1            48.10               449.0                         328.0
# 2            47.33               448.0                         323.0
# 3            42.27               438.0                         254.0
# 4            38.41               428.0                         187.0
#
#    generation fossil coal-derived gas  generation fossil gas  \
# 0                                 0.0                 4844.0
# 1                                 0.0                 5196.0
# 2                                 0.0                 4857.0
# 3                                 0.0                 4314.0
# 4                                 0.0                 4130.0
#
#    generation fossil hard coal  ...  generation marine  generation nuclear  \
# 0                       4821.0  ...                0.0              7096.0
# 1                       4755.0  ...                0.0              7096.0
# 2                       4581.0  ...                0.0              7099.0
# 3                       4131.0  ...                0.0              7098.0
# 4                       3840.0  ...                0.0              7097.0
#
#    generation other  generation other renewables  generation solar  \
# 0              43.0                         73.0              49.0
# 1              43.0                         71.0              50.0
# 2              43.0                         73.0              50.0
# 3              43.0                         75.0              50.0
# 4              43.0                         74.0              42.0
#
#    generation solar forecast  generation waste  generation wind offshore  \
# 0                       17.0             196.0                       0.0
# 1                       16.0             195.0                       0.0
# 2                        8.0             196.0                       0.0
# 3                        2.0             191.0                       0.0
# 4                        9.0             189.0                       0.0
#
#    generation wind onshore  generation wind onshore forecast
# 0                   6378.0                            6436.0
# 1                   5890.0                            5856.0
# 2                   5461.0                            5454.0
# 3                   5238.0                            5151.0
# 4                   4935.0                            4861.0
#
# [5 rows x 27 columns]

# %%
df['time'] = pd.to_datetime(df['time'])
df.set_index('time', inplace=True)
# Time features
df['hour']        = df.index.hour
df['day_of_week'] = df.index.dayofweek
df['month']       = df.index.month
df['quarter']     = df.index.quarter
df['is_weekend']  = (df.index.dayofweek >= 5).astype(int)

# Lag features
# Price lags: 1h ago, 24h ago (same hour yesterday), 168h ago (same hour last week)
for lag in [1, 24, 168]:
    df[f'price_lag_{lag}h'] = df['price actual'].shift(lag)

# Load lags
for lag in [1, 24]:
    df[f'load_lag_{lag}h'] = df['total load actual'].shift(lag)

# Moving average features
# shift(1) ensures no data leakage — we only use past values
df['price_ma_24h']  = df['price actual'].shift(1).rolling(24).mean()
df['price_ma_168h'] = df['price actual'].shift(1).rolling(168).mean()
df['price_std_24h'] = df['price actual'].shift(1).rolling(24).std()
df['load_ma_24h']   = df['total load actual'].shift(1).rolling(24).mean()

# Drop NaN rows from lag/rolling
df.dropna(inplace=True)
print(f'Final shape after feature engineering: {df.shape}')
# Out:
# Final shape after feature engineering: (330, 40)

# %%
import joblib
import tensorflow as tf

# Load Ridge model
model = joblib.load('model_ridge.pkl')

# Load standard scaler
scaler_std = joblib.load('scaler_standard.pkl')

print("Model and scalers loaded successfully!")
# Out:
# Model and scalers loaded successfully!

# %%
import json

with open('feature_columns.json', 'r') as f:
    feature_columns = json.load(f)

print(len(feature_columns))
print(feature_columns)
# Out:
# 38
# ['generation biomass', 'generation fossil brown coal/lignite', 'generation fossil coal-derived gas', 'generation fossil gas', 'generation fossil hard coal', 'generation fossil oil', 'generation fossil oil shale', 'generation fossil peat', 'generation geothermal', 'generation hydro pumped storage consumption', 'generation hydro run-of-river and poundage', 'generation hydro water reservoir', 'generation marine', 'generation nuclear', 'generation other', 'generation other renewable', 'generation solar', 'generation waste', 'generation wind offshore', 'generation wind onshore', 'forecast solar day ahead', 'forecast wind onshore day ahead', 'total load forecast', 'total load actual', 'hour', 'day_of_week', 'month', 'quarter', 'is_weekend', 'price_lag_1h', 'price_lag_24h', 'price_lag_168h', 'load_lag_1h', 'load_lag_24h', 'price_ma_24h', 'price_ma_168h', 'price_std_24h', 'load_ma_24h']

# %%
# Check which feature columns are missing from your df
missing = [col for col in feature_columns if col not in df.columns]
print("Missing columns:", missing)

# Check which columns in df are not in feature_columns
extra = [col for col in df.columns if col not in feature_columns]
print("Extra columns:", extra)
# Out:
# Missing columns: ['generation fossil brown coal/lignite', 'generation other renewable', 'forecast solar day ahead', 'forecast wind onshore day ahead']
# Extra columns: ['price actual', 'price day ahead', 'generation fossil brown coal', 'generation other renewables', 'generation solar forecast', 'generation wind onshore forecast']

# %%
df.rename(columns={
    'generation fossil brown coal': 'generation fossil brown coal/lignite',
    'generation other renewables': 'generation other renewable',
    'generation solar forecast': 'forecast solar day ahead',
    'generation wind onshore forecast': 'forecast wind onshore day ahead'
}, inplace=True)

# %%
missing = [col for col in feature_columns if col not in df.columns]
print("Missing columns:", missing)

extra = [col for col in df.columns if col not in feature_columns]
print("Extra columns:", extra)
# Out:
# Missing columns: []
# Extra columns: ['price actual', 'price day ahead']

# %%
X_input = scaler_std.transform(df[feature_columns].values[-1].reshape(1, -1))
prediction = model.predict(X_input)
print(f"Predicted electricity price: {prediction[0]:.2f} €/MWh")
# Out:
# Predicted electricity price: 83.14 €/MWh
